# %% [markdown]
# <a href="https://colab.research.google.com/github/ZahraAlijani/pop_estim/blob/main/neutrosophic_general_final.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

# Data from Table 4: MSE using actual data
mse_values_actual = {
    'Y̅_UN': [0.004771434, 0.004771434],
    'Y̅_RN': [0.001176741, 0.004079918],
    'Y̅_PN': [0.01574454, 0.01290342],
    'Y̅_DN': [0.002050780, 0.001895328],
    'Y̅_BTRN': [0.002051786, 0.003495617],
    'Y̅_BTPN': [0.009335684, 0.007907368],
    'Y ̅  ̂_SN1':[0.002051822, 0.003495624],
'Y ̅  ̂_SN2':[0.002077862, 0.003500653],
    'Y ̅  ̂_SN3':[0.002051802, 0.00349562],
'Y ̅  ̂_SN4':[0.004184703, 0.004426577],
   'Y ̅  ̂_SN5':[0.002062184, 0.003496803],
   'Y ̅  ̂_SN6':[ 0.003647159, 0.003956309],
      'Y ̅  ̂_SN7':[0.002051827, 0.00349563],
    'Y ̅  ̂_SN8':[0.002056549, 0.003496158],
    'Y ̅  ̂_SN9':[0.002081793, 0.003505421],
    'Y ̅  ̂_SN10':[0.004756275, 0.004771342],
'Y ̅  ̂_(Prop,N1)^((*))':[0.001176135, 0.003463482],
    'Y ̅  ̂_(Prop,N2)^((*))':[0.001176136, 0.003463481],
'Y ̅  ̂_(Prop,N3)^((*))':[0.001176135, 0.003463482],
    'Y ̅  ̂_(Prop,N4)^((*))': [0.001176135, 0.003463482],
    'Y ̅  ̂_(Prop,N5)^((*))':[0.001176135, 0.003463482],
    'Y ̅  ̂_(Prop,N6)^((*))':[0.001176135, 0.003463482],
    'Y ̅  ̂_(Prop,N7)^((*))':[0.001176135, 0.003463482],
    'Y ̅  ̂_(Prop,N8)^((*))':[0.001176135, 0.003463482],
    'Y ̅  ̂_(Prop,N9)^((*))':[0.001176135, 0.003463482],
    'Y ̅  ̂_(Prop,N10)^((*))':[0.001176135, 0.003463482],
}

# Data from Table 5: PRE using actual data
pre_values_actual = {
    'Y̅_UN': [100, 100],
    'Y̅_RN': [116.9493, 405.4787],
    'Y̅_PN': [30.30533, 36.97806],
    'Y̅_DN': [138.28, 251.7471],
    'Y̅_BTRN': [136.4976, 232.5503],
    'Y̅_BTPN': [51.10963, 60.34162],
    'Y ̅  ̂_SN1':[136.4973, 232.5462],
'Y ̅  ̂_SN2':[136.3012, 229.6319],
    'Y ̅  ̂_SN3':[136.4975, 232.5484],
'Y ̅  ̂_SN4':[107.7906, 114.0208],
   'Y ̅  ̂_SN5':[136.4513, 231.3777],
   'Y ̅  ̂_SN6':[120.6031, 130.8261],
      'Y ̅  ̂_SN7':[136.4971, 232.5456],
    'Y ̅  ̂_SN8':[136.4765, 232.0116],
    'Y ̅  ̂_SN9':[136.1159, 229.1983],
    'Y ̅  ̂_SN10':[100.0019, 100.3187],
'Y ̅  ̂_(Prop,N1)^((*))':[137.7641, 405.6875],
    'Y ̅  ̂_(Prop,N2)^((*))':[137.7642, 405.6875],
'Y ̅  ̂_(Prop,N3)^((*))':[137.7631, 405.6865],
    'Y ̅  ̂_(Prop,N4)^((*))': [137.7631, 405.6864],
    'Y ̅  ̂_(Prop,N5)^((*))':[137.7661, 405.6895],
    'Y ̅  ̂_(Prop,N6)^((*))':[137.7641, 405.6874],
    'Y ̅  ̂_(Prop,N7)^((*))':[137.7641, 405.6875],
    'Y ̅  ̂_(Prop,N8)^((*))':[137.7641, 405.6875],
    'Y ̅  ̂_(Prop,N9)^((*))':[137.7641, 405.6875],
    'Y ̅  ̂_(Prop,N10)^((*))':[137.7641, 405.6874],
}

# Plotting
plt.figure(figsize=(15, 26))

# Plot for MSE
plt.subplot(1, 2, 1)
for estimator, mse_values in mse_values_actual.items():
    plt.plot(range(len(mse_values)), mse_values, marker='o', label=estimator)
plt.title('Mean Squared Errors (MSEs) for Different Estimators (Actual Data)')
plt.xlabel('Parameter Combinations')
plt.ylabel('MSE Values')
plt.xticks(range(len(mse_values)), ['For a=1, b=C_xN', 'For a=1, b=β_(2(xN))'])
plt.legend()
plt.grid(True)

# Plot for PRE
plt.subplot(1, 2, 2)
for estimator, pre_values in pre_values_actual.items():
    plt.plot(range(len(pre_values)), pre_values, marker='o', label=estimator)
plt.title('Percentage relative efficiency (PREs) for Different Estimators (Actual Data)')
plt.xlabel('Parameter Combinations')
plt.ylabel('Percentage relative efficiency')
plt.xticks(range(len(pre_values)), ['For a=1, b=C_xN', 'For a=1, b=β_(2(xN))'])
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Data from Table 7: MSE using simulation
estimators_mse = ['Y̅_UN', 'Y̅_RN', 'Y̅_PN', 'Y̅_DN', 'Y̅_BTRN', 'Y̅_BTPN','Y ̅  ̂_SN1','Y ̅  ̂_SN2','Y ̅  ̂_SN3','Y ̅  ̂_SN4','Y ̅  ̂_SN5','Y ̅  ̂_SN6','Y ̅  ̂_SN7','Y ̅  ̂_SN8','Y ̅  ̂_SN9','Y ̅  ̂_SN10','Y ̅  ̂_(Prop,N1)^((*))','Y ̅  ̂_(Prop,N2)^((*))','Y ̅  ̂_(Prop,N3)^((*))','Y ̅  ̂_(Prop,N4)^((*))','Y ̅  ̂_(Prop,N5)^((*))','Y ̅  ̂_(Prop,N6)^((*))','Y ̅  ̂_(Prop,N7)^((*))','Y ̅  ̂_(Prop,N8)^((*))','Y ̅  ̂_(Prop,N9)^((*))','Y ̅  ̂_(Prop,N10)^((*))']
mse_values_simulation = {
    'Y̅_UN': [0.2619458, 0.2619458],
    'Y̅_RN': [0.1290996, 0.1497684],
    'Y̅_PN': [0.448552, 0.4089126],
    'Y̅_DN': [0.02566218, 0.02260200],
    'Y̅_BTRN': [0.1888027, 0.2015085],
    'Y̅_BTPN': [0.3310805, 0.3485289],
    'Y ̅  ̂_SN1':[0.2022682, 0.1893483],
    'Y ̅  ̂_SN2':[0.2082852, 0.1952096],
    'Y ̅  ̂_SN3':[0.2017871, 0.1890021],
    'Y ̅  ̂_SN4':[0.2204352, 0.2113867],
    'Y ̅  ̂_SN5':[0.2040597, 0.1911544],
    'Y ̅  ̂_SN6':[0.2098011, 0.1985855],
    'Y ̅  ̂_SN7':[0.2022997, 0.1893758],
    'Y ̅  ̂_SN8':[0.202462, 0.1896759],
    'Y ̅  ̂_SN9':[0.2085363, 0.1955049],
    'Y ̅  ̂_SN10':[0.2618358, 0.2617713],
    'Y ̅  ̂_(Prop,N1)^((*))':[0.02465215, 0.02063134],
    'Y ̅  ̂_(Prop,N2)^((*))':[0.02465263, 0.02063211],
    'Y ̅  ̂_(Prop,N3)^((*))':[0.02465212, 0.02063127],
    'Y ̅  ̂_(Prop,N4)^((*))': [0.02465366, 0.02063334],
    'Y ̅  ̂_(Prop,N5)^((*))':[0.0246523, 0.02063158],
    'Y ̅  ̂_(Prop,N6)^((*))':[0.02465288, 0.02063229],
    'Y ̅  ̂_(Prop,N7)^((*))':[0.02465215, 0.02063134],
    'Y ̅  ̂_(Prop,N8)^((*))':[0.02465218, 0.02063136],
    'Y ̅  ̂_(Prop,N9)^((*))':[0.2465265, 0.02063214],
    'Y ̅  ̂_(Prop,N10)^((*))':[0.02465485, 0.02063499],
}

# Data from Table 8: PRE using simulation
estimators_pre = ['Y̅_UN', 'Y̅_RN', 'Y̅_PN', 'Y̅_DN', 'Y̅_BTRN', 'Y̅_BTPN', 'Y ̅  ̂_SN1','Y ̅  ̂_SN2','Y ̅  ̂_SN3','Y ̅  ̂_SN4','Y ̅  ̂_SN5','Y ̅  ̂_SN6','Y ̅  ̂_SN7','Y ̅  ̂_SN8','Y ̅  ̂_SN9','Y ̅  ̂_SN10','Y ̅  ̂_(Prop,N1)^((*))','Y ̅  ̂_(Prop,N2)^((*))','Y ̅  ̂_(Prop,N3)^((*))','Y ̅  ̂_(Prop,N4)^((*))','Y ̅  ̂_(Prop,N5)^((*))','Y ̅  ̂_(Prop,N6)^((*))','Y ̅  ̂_(Prop,N7)^((*))','Y ̅  ̂_(Prop,N8)^((*))','Y ̅  ̂_(Prop,N9)^((*))','Y ̅  ̂_(Prop,N10)^((*))']
pre_values_simulation = {
    'Y̅_UN': [100, 100],
    'Y̅_RN': [202.9022, 174.9006],
    'Y̅_PN': [58.3981, 64.05912],
    'Y̅_DN': [1022.347, 1158.95],
    'Y̅_BTRN': [129.9925, 138.7405],
    'Y̅_BTPN': [75.15756, 79.11846],
    'Y ̅  ̂_SN1':[129.5042, 138.3407 ],
    'Y ̅  ̂_SN2':[125.7631, 134.1869 ],
    'Y ̅  ̂_SN3':[129.813, 138.5941 ],
    'Y ̅  ̂_SN4':[118.8312, 123.9178 ],
    'Y ̅  ̂_SN5':[128.3673, 137.0336 ],
    'Y ̅  ̂_SN6':[124.8543, 131.9058 ],
    'Y ̅  ̂_SN7':[129.4841, 138.3207],
    'Y ̅  ̂_SN8':[129.3802, 138.1018 ],
    'Y ̅  ̂_SN9':[125.6116, 133.9843 ],
    'Y ̅  ̂_SN10':[100.042, 100.0667],
    'Y ̅  ̂_(Prop,N1)^((*))':[1062.568, 1269.65],
    'Y ̅  ̂_(Prop,N2)^((*))':[1062.547, 1269.603],
    'Y ̅  ̂_(Prop,N3)^((*))':[1062.569, 1269.654],
    'Y ̅  ̂_(Prop,N4)^((*))': [1062.503, 1269.527],
    'Y ̅  ̂_(Prop,N5)^((*))':[1062.561, 1269.635],
    'Y ̅  ̂_(Prop,N6)^((*))':[1062.537, 1269.592],
    'Y ̅  ̂_(Prop,N7)^((*))':[1062.568, 1269.65],
    'Y ̅  ̂_(Prop,N8)^((*))':[1062.567, 1269.649],
    'Y ̅  ̂_(Prop,N9)^((*))':[1062.546,1269.601],
    'Y ̅  ̂_(Prop,N10)^((*))':[1062.451, 1269.426],
}

# Plotting
plt.figure(figsize=(15, 26))

# Plot for MSE
plt.subplot(1, 2, 1)
for estimator in estimators_mse:
  plt.plot(range(len(mse_values_simulation[estimator])), mse_values_simulation[estimator], marker='o', label=estimator)
plt.title('Mean Squared Errors (MSEs) for Different Estimators (Simulation)')
plt.xlabel('Parameter Combinations')
plt.ylabel('MSE Values')
plt.xticks(range(len(mse_values_simulation['Y̅_UN'])), ['For a=1, b=C_xN', 'For a=1, b=β_(2(xN))'])
plt.legend()
plt.grid(True)

# Plot for PRE

plt.subplot(1, 2, 2)
for estimator in estimators_pre:
    plt.plot(range(len(pre_values_simulation[estimator])), pre_values_simulation[estimator], marker='o', label=estimator)
plt.title('Percentage Relative Efficiency (PREs) for Different Estimators (Simulation)')
plt.xlabel('Parameter Combinations')
plt.ylabel('Percentage Relative Efficiency')
plt.xticks(range(len(pre_values_simulation['Y̅_UN'])), ['For a=1, b=C_xN', 'For a=1, b=β_(2(xN))'])
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Data from Table 4: MSE using actual data
mse_values_actual = {
    'Y̅_UN': [0.004771434, 0.004771434],
    'Y̅_RN': [0.001176741, 0.004079918],
    'Y̅_PN': [0.01574454, 0.01290342],
    'Y̅_DN': [0.002050780, 0.001895328],
    'Y̅_BTRN': [0.002051786, 0.003495617],
    'Y̅_BTPN': [0.009335684, 0.007907368],
    'Y ̅ ̂_SN1': [0.002051822, 0.003495624],
    'Y ̅ ̂_SN2': [0.002077862, 0.003500653],
    'Y ̅ ̂_SN3': [0.002051802, 0.00349562],
    'Y ̅ ̂_SN4': [0.004184703, 0.004426577],
    'Y ̅ ̂_SN5': [0.002062184, 0.003496803],
    'Y ̅ ̂_SN6': [0.003647159, 0.003956309],
    'Y ̅ ̂_SN7': [0.002051827, 0.00349563],
    'Y ̅ ̂_SN8': [0.002056549, 0.003496158],
    'Y ̅ ̂_SN9': [0.002081793, 0.003505421],
    'Y ̅ ̂_SN10': [0.004756275, 0.004771342],
    'Y ̅ ̂_(Prop,N1)^((*))': [0.001176135, 0.003463482],
    'Y ̅ ̂_(Prop,N2)^((*))': [0.001176136, 0.003463481],
    'Y ̅ ̂_(Prop,N3)^((*))': [0.001176135, 0.003463482],
    'Y ̅ ̂_(Prop,N4)^((*))': [0.001176135, 0.003463482],
    'Y ̅ ̂_(Prop,N5)^((*))': [0.001176135, 0.003463482],
    'Y ̅ ̂_(Prop,N6)^((*))': [0.001176135, 0.003463482],
    'Y ̅ ̂_(Prop,N7)^((*))': [0.001176135, 0.003463482],
    'Y ̅ ̂_(Prop,N8)^((*))': [0.001176135, 0.003463482],
    'Y ̅ ̂_(Prop,N9)^((*))': [0.001176135, 0.003463482],
    'Y ̅ ̂_(Prop,N10)^((*))': [0.001176135, 0.003463482],
}

# Data from Table 5: PRE using actual data
pre_values_actual = {
    'Y̅_UN': [100, 100],
    'Y̅_RN': [116.9493, 405.4787],
    'Y̅_PN': [30.30533, 36.97806],
    'Y̅_DN': [138.28, 251.7471],
    'Y̅_BTRN': [136.4976, 232.5503],
    'Y̅_BTPN': [51.10963, 60.34162],
    'Y ̅ ̂_SN1': [136.4973, 232.5462],
    'Y ̅ ̂_SN2': [136.3012, 229.6319],
    'Y ̅ ̂_SN3': [136.4975, 232.5484],
    'Y ̅ ̂_SN4': [107.7906, 114.0208],
    'Y ̅ ̂_SN5': [136.4513, 231.3777],
    'Y ̅ ̂_SN6': [120.6031, 130.8261],
    'Y ̅ ̂_SN7': [136.4971, 232.5456],
    'Y ̅ ̂_SN8': [136.4765, 232.0116],
    'Y ̅ ̂_SN9': [136.1159, 229.1983],
    'Y ̅ ̂_SN10': [100.0019, 100.3187],
    'Y ̅ ̂_(Prop,N1)^((*))': [137.7641, 405.6875],
    'Y ̅ ̂_(Prop,N2)^((*))': [137.7642, 405.6875],
    'Y ̅ ̂_(Prop,N3)^((*))': [137.7631, 405.6865],
    'Y ̅ ̂_(Prop,N4)^((*))': [137.7631, 405.6864],
    'Y ̅ ̂_(Prop,N5)^((*))': [137.7661, 405.6895],
    'Y ̅ ̂_(Prop,N6)^((*))': [137.7641, 405.6874],
    'Y ̅ ̂_(Prop,N7)^((*))': [137.7641, 405.6875],
    'Y ̅ ̂_(Prop,N8)^((*))': [137.7641, 405.6875],
    'Y ̅ ̂_(Prop,N9)^((*))': [137.7641, 405.6875],
    'Y ̅ ̂_(Prop,N10)^((*))': [137.7641, 405.6874],
}

# Plotting
plt.figure(figsize=(14, 6))

# Plot for MSE
plt.subplot(1, 2, 1)
for estimator, mse_values in mse_values_actual.items():
    plt.plot(range(len(mse_values)), mse_values, marker='o', label=estimator)
plt.title('Mean Squared Errors (MSEs)')
plt.xlabel('Parameter Combinations')
plt.ylabel('MSE Values')
plt.xticks(range(len(mse_values)), ['a=1, b=C_xN', 'a=1, b=β_(2(xN))'])
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5), fontsize='small', frameon=False)

# Plot for PRE
plt.subplot(1, 2, 2)
for estimator, pre_values in pre_values_actual.items():
    plt.plot(range(len(pre_values)), pre_values, marker='o', label=estimator)
plt.title('Percentage Relative Efficiency (PREs)')
plt.xlabel('Parameter Combinations')
plt.ylabel('Percentage Relative Efficiency')
plt.xticks(range(len(pre_values)), ['a=1, b=C_xN', 'a=1, b=β_(2(xN))'])
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5), fontsize='small', frameon=False)

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Data from Table 7: MSE using simulation
estimators_mse = ['Y̅_UN', 'Y̅_RN', 'Y̅_PN', 'Y̅_DN', 'Y̅_BTRN', 'Y̅_BTPN', 'Y ̅ ̂_SN1', 'Y ̅ ̂_SN2', 'Y ̅ ̂_SN3', 'Y ̅ ̂_SN4', 'Y ̅ ̂_SN5', 'Y ̅ ̂_SN6', 'Y ̅ ̂_SN7', 'Y ̅ ̂_SN8', 'Y ̅ ̂_SN9', 'Y ̅ ̂_SN10', 'Y ̅ ̂_(Prop,N1)^((*))', 'Y ̅ ̂_(Prop,N2)^((*))', 'Y ̅ ̂_(Prop,N3)^((*))', 'Y ̅ ̂_(Prop,N4)^((*))', 'Y ̅ ̂_(Prop,N5)^((*))', 'Y ̅ ̂_(Prop,N6)^((*))', 'Y ̅ ̂_(Prop,N7)^((*))', 'Y ̅ ̂_(Prop,N8)^((*))', 'Y ̅ ̂_(Prop,N9)^((*))', 'Y ̅ ̂_(Prop,N10)^((*))']
mse_values_simulation = {
    'Y̅_UN': [0.2619458, 0.2619458],
    'Y̅_RN': [0.1290996, 0.1497684],
    'Y̅_PN': [0.448552, 0.4089126],
    'Y̅_DN': [0.02566218, 0.02260200],
    'Y̅_BTRN': [0.1888027, 0.2015085],
    'Y̅_BTPN': [0.3310805, 0.3485289],
    'Y ̅ ̂_SN1': [0.2022682, 0.1893483],
    'Y ̅ ̂_SN2': [0.2082852, 0.1952096],
    'Y ̅ ̂_SN3': [0.2017871, 0.1890021],
    'Y ̅ ̂_SN4': [0.2204352, 0.2113867],
    'Y ̅ ̂_SN5': [0.2040597, 0.1911544],
    'Y ̅ ̂_SN6': [0.2098011, 0.1985855],
    'Y ̅ ̂_SN7': [0.2022997, 0.1893758],
    'Y ̅ ̂_SN8': [0.202462, 0.1896759],
    'Y ̅ ̂_SN9': [0.2085363, 0.1955049],
    'Y ̅ ̂_SN10': [0.2618358, 0.2617713],
    'Y ̅ ̂_(Prop,N1)^((*))': [0.02465215, 0.02063134],
    'Y ̅ ̂_(Prop,N2)^((*))': [0.02465263, 0.02063211],
    'Y ̅ ̂_(Prop,N3)^((*))': [0.02465212, 0.02063127],
    'Y ̅ ̂_(Prop,N4)^((*))': [0.02465366, 0.02063334],
    'Y ̅ ̂_(Prop,N5)^((*))': [0.0246523, 0.02063158],
    'Y ̅ ̂_(Prop,N6)^((*))': [0.02465288, 0.02063229],
    'Y ̅ ̂_(Prop,N7)^((*))': [0.02465215, 0.02063134],
    'Y ̅ ̂_(Prop,N8)^((*))': [0.02465218, 0.02063136],
    'Y ̅ ̂_(Prop,N9)^((*))': [0.2465265, 0.02063214],
    'Y ̅ ̂_(Prop,N10)^((*))': [0.02465485, 0.02063499],
}

# Data from Table 8: PRE using simulation
estimators_pre = ['Y̅_UN', 'Y̅_RN', 'Y̅_PN', 'Y̅_DN', 'Y̅_BTRN', 'Y̅_BTPN', 'Y ̅ ̂_SN1', 'Y ̅ ̂_SN2', 'Y ̅ ̂_SN3', 'Y ̅ ̂_SN4', 'Y ̅ ̂_SN5', 'Y ̅ ̂_SN6', 'Y ̅ ̂_SN7', 'Y ̅ ̂_SN8', 'Y ̅ ̂_SN9', 'Y ̅ ̂_SN10', 'Y ̅ ̂_(Prop,N1)^((*))', 'Y ̅ ̂_(Prop,N2)^((*))', 'Y ̅ ̂_(Prop,N3)^((*))', 'Y ̅ ̂_(Prop,N4)^((*))', 'Y ̅ ̂_(Prop,N5)^((*))', 'Y ̅ ̂_(Prop,N6)^((*))', 'Y ̅ ̂_(Prop,N7)^((*))', 'Y ̅ ̂_(Prop,N8)^((*))', 'Y ̅ ̂_(Prop,N9)^((*))', 'Y ̅ ̂_(Prop,N10)^((*))']
pre_values_simulation = {
    'Y̅_UN': [100, 100],
    'Y̅_RN': [202.9022, 174.9006],
    'Y̅_PN': [58.3981, 64.05912],
    'Y̅_DN': [1022.347, 1158.95],
    'Y̅_BTRN': [129.9925, 138.7405],
    'Y̅_BTPN': [75.15756, 79.11846],
    'Y ̅ ̂_SN1': [129.5042, 138.3407],
    'Y ̅ ̂_SN2': [125.7631, 134.1869],
    'Y ̅ ̂_SN3': [129.813, 138.5941],
    'Y ̅ ̂_SN4': [118.8312, 123.9178],
    'Y ̅ ̂_SN5': [128.3673, 137.0336],
    'Y ̅ ̂_SN6': [124.8543, 131.9058],
    'Y ̅ ̂_SN7': [129.4841, 138.3207],
    'Y ̅ ̂_SN8': [129.3802, 138.1018],
    'Y ̅ ̂_SN9': [125.6116, 133.9843],
    'Y ̅ ̂_SN10': [100.042, 100.0667],
    'Y ̅ ̂_(Prop,N1)^((*))': [1062.568, 1269.65],
    'Y ̅ ̂_(Prop,N2)^((*))': [1062.547, 1269.603],
    'Y ̅ ̂_(Prop,N3)^((*))': [1062.569, 1269.654],
    'Y ̅ ̂_(Prop,N4)^((*))': [1062.503, 1269.527],
    'Y ̅ ̂_(Prop,N5)^((*))': [1062.561, 1269.635],
    'Y ̅ ̂_(Prop,N6)^((*))': [1062.537, 1269.592],
    'Y ̅ ̂_(Prop,N7)^((*))': [1062.568, 1269.65],
    'Y ̅ ̂_(Prop,N8)^((*))': [1062.567, 1269.649],
    'Y ̅ ̂_(Prop,N9)^((*))': [1062.546, 1269.601],
    'Y ̅ ̂_(Prop,N10)^((*))': [1062.451, 1269.426],
}

# Plotting
plt.figure(figsize=(15, 8))

# Plot for MSE
plt.subplot(1, 2, 1)
for estimator in estimators_mse:
    plt.plot(range(len(mse_values_simulation[estimator])), mse_values_simulation[estimator], marker='o', label=estimator)
plt.title('Mean Squared Errors (MSEs) for Different Estimators (Simulation)')
plt.xlabel('Parameter Combinations')
plt.ylabel('MSE Values')
plt.xticks(range(len(mse_values_simulation['Y̅_UN'])), ['For a=1, b=C_xN', 'For a=1, b=β_(2(xN))'])
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.grid(True)

# Plot for PRE
plt.subplot(1, 2, 2)
for estimator in estimators_pre:
    plt.plot(range(len(pre_values_simulation[estimator])), pre_values_simulation[estimator], marker='o', label=estimator)
plt.title('Percentage Relative Efficiency (PREs) for Different Estimators (Simulation)')
plt.xlabel('Parameter Combinations')
plt.ylabel('Percentage Relative Efficiency')
plt.xticks(range(len(pre_values_simulation['Y̅_UN'])), ['For a=1, b=C_xN', 'For a=1, b=β_(2(xN))'])
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.grid(True)

plt.tight_layout()
plt.show()
